# %%
from sklearn.cluster import KMeans
from sklearn.metrics import classification_report,confusion_matrix,accuracy_score
from sklearn.metrics.cluster import contingency_matrix
import numpy as np
import pandas as pd
import random
import math
import copy

# %%
k = 5

# %%
df=pd.read_csv("data_final_deep.csv")
# df

# %%
Y = []
for i in df['xAttack']:
    if i=="normal":
        Y.append(0)
    elif i=="dos":
        Y.append(1)
    elif i=="r2l":
        Y.append(2)
    elif i=="probe":
        Y.append(3)
    elif i=="u2r":
        Y.append(4)

# %%
X = df.iloc[:,0:14].values
kmeans = KMeans(n_clusters=5).fit(X)
kmeans.labels_
X
# Out:
# array([[0.84902177, 0.8448608 , 0.84308496, ..., 0.85015785, 0.84556021,
#         0.84667182],
#        [0.80426793, 0.80019638, 0.79827975, ..., 0.80592719, 0.80110199,
#         0.8025164 ],
#        [0.78803915, 0.78406033, 0.78170094, ..., 0.78968705, 0.78495992,
#         0.78600073],
#        ...,
#        [0.83265752, 0.82842734, 0.82666033, ..., 0.83400816, 0.82922069,
#         0.83028288],
#        [0.79071004, 0.78668971, 0.7842709 , ..., 0.79223445, 0.78757703,
#         0.78860465],
#        [0.84998933, 0.84581503, 0.84409876, ..., 0.85112144, 0.84653713,
#         0.84767035]])

# %%
kmeans.cluster_centers_
cn = contingency_matrix(kmeans.labels_,Y)
print(cn)
ans = 0
for i in cn:
    ans = ans + max(i)
purity = ans/len(df)
print(purity)
# Out:
# [[ 3676 33765     9  1429     1]
#  [55984  2112   679  4327    30]
#  [   49     0     0  2720     0]
#  [ 7553  3165   258   884    21]
#  [   81  6885    49  2296     0]]
# 0.8486501075627317

# %%
ypred = kmeans.predict(X)
print(ypred)
# Out:
# [1 0 0 ... 3 0 1]

# %%
X.shape
# Out:
# (125973, 14)

# %%
def euclid(a,b):
    return np.sqrt(np.sum((a-b)**2))

# %%
n = X.shape[0]
d = X.shape[1]
clusters = np.zeros(n)
distances = np.zeros((n,k))
mean = np.mean(X, axis = 0)
std = np.std(X, axis = 0)
centers_new = np.random.randn(k,d)*std + mean
centers_old = np.zeros([k,d])

# %%
d
# Out:
# 14

# %%
print(centers_old.shape)
print(centers_new.shape)
# Out:
# (5, 14)
# (5, 14)

# %%
error = 0
for i in range(5):
    error = error + euclid(centers_new[i], centers_old[i])

print(error)
# Out:
# 15.624605125174371

# %%
iteration = 0
force = False
while (error != 0) or iteration<1000:
    force = False
    for i in range(k):
        distances[:,i] = np.linalg.norm(X - centers_new[i], axis=1)
    
    clusters = np.argmin(distances, axis = 1)
    
    centers_old = copy.deepcopy(centers_new)
    for i in range(k):
        member = 0
        new_center = [0] * d
        
        for c in range(len(clusters)):
            if clusters[c] == i:
                member = member + 1
                for j in range(0,d):
                    new_center[j] += X[c][j]
        
        print("M=",member)
        if member == 0:
#             pass
            force = True
#             iteration = 0
            centers_old = np.zeros([k,d])
            centers_new = np.random.randn(k,d)*std + mean
            break
        else:
            new_center = np.array(new_center)
            centers_new[i] = new_center/member
        
#     print("d=",d)
    print("FLAG = ",force)
    error = 0
    for i in range(5):
        error = error + euclid(centers_new[i], centers_old[i])
    iteration = iteration + 1
    print(error)
    print(iteration)
    if error == 0 and force == False:
        break
# Out:
# M= 0
# FLAG =  True
# 15.429819972009351
# 1
# M= 0
# FLAG =  True
# 15.380431307613797
# 2
# M= 0
# FLAG =  True
# 15.4398092434211
# 3
# M= 0
# FLAG =  True
# 15.499746261199492
# 4
# M= 0
# FLAG =  True
# 15.392096552626008
# 5
# M= 0
# FLAG =  True
# 15.500416788639516
# 6
# M= 48393
# M= 0
# FLAG =  True
# 15.390688232721864
# 7
# M= 0
# FLAG =  True
# 15.229075690162894
# 8
# M= 0
# FLAG =  True
# 15.329127134342096
# 9
# M= 0
# FLAG =  True
# 15.15701934642129
# 10
# M= 0
# FLAG =  True
# 15.290041126617286
# 11
# M= 50746
# M= 0
# FLAG =  True
# 15.50652324880134
# 12
# M= 0
# FLAG =  True
# 15.437899185516363
# 13
# M= 51656
# M= 1795
# M= 72522
# M= 0
# FLAG =  True
# 15.43057332591399
# 14
# M= 28213
# M= 0
# FLAG =  True
# 15.632838229943573
# 15
# M= 0
# FLAG =  True
# 15.518282353718504
# 16
# M= 55477
# M= 58156
# M= 12340
# M= 0
# FLAG =  True
# 15.372553293584414
# 17
# M= 74696
# M= 0
# FLAG =  True
# 15.436220096116834
# 18
# M= 60133
# M= 0
# FLAG =  True
# 15.461672734515634
# 19
# M= 20647
# M= 48877
# M= 0
# FLAG =  True
# 15.238468497793743
# 20
# M= 0
# FLAG =  True
# 15.386981865694086
# 21
# M= 0
# FLAG =  True
# 15.554406931608455
# 22
# M= 26077
# M= 33775
# M= 4142
# M= 61979
# M= 0
# FLAG =  True
# 15.389061654497551
# 23
# M= 73078
# M= 19368
# M= 33527
# M= 0
# FLAG =  True
# 15.433790260893272
# 24
# M= 56326
# M= 0
# FLAG =  True
# 15.379704326972247
# 25
# M= 0
# FLAG =  True
# 15.39240253449721
# 26
# M= 52951
# M= 0
# FLAG =  True
# 15.316441401777885
# 27
# M= 77412
# M= 0
# FLAG =  True
# 15.347830657384211
# 28
# M= 0
# FLAG =  True
# 15.591295439512182
# 29
# M= 54553
# M= 0
# FLAG =  True
# 15.31554409518362
# 30
# M= 46245
# M= 62915
# M= 0
# FLAG =  True
# 15.526702771204397
# 31
# M= 22803
# M= 47686
# M= 47749
# M= 7735
# M= 0
# FLAG =  True
# 15.483780853519074
# 32
# M= 65938
# M= 0
# FLAG =  True
# 15.507684977524953
# 33
# M= 56456
# M= 0
# FLAG =  True
# 15.416289306500518
# 34
# M= 11716
# M= 63399
# M= 16322
# M= 0
# FLAG =  True
# 15.365596249597065
# 35
# M= 0
# FLAG =  True
# 15.255926188002075
# 36
# M= 44294
# M= 14623
# M= 67056
# M= 0
# FLAG =  True
# 15.441135014477434
# 37
# M= 13
# M= 0
# FLAG =  True
# 15.422398077125651
# 38
# M= 68611
# M= 0
# FLAG =  True
# 15.210064388263232
# 39
# M= 29
# M= 0
# FLAG =  True
# 15.44045837156662
# 40
# M= 0
# FLAG =  True
# 15.496169105633117
# 41
# M= 82680
# M= 0
# FLAG =  True
# 15.339012379819817
# 42
# M= 0
# FLAG =  True
# 15.475775553916673
# 43
# M= 0
# FLAG =  True
# 15.47290857340493
# 44
# M= 77206
# M= 11420
# M= 154
# M= 0
# FLAG =  True
# 15.574370090423105
# 45
# M= 20443
# M= 54485
# M= 0
# FLAG =  True
# 15.542951656723455
# 46
# M= 14282
# M= 0
# FLAG =  True
# 15.497616058566454
# 47
# M= 125783
# M= 0
# FLAG =  True
# 15.381366957152776
# 48
# M= 0
# FLAG =  True
# 15.563582559311008
# 49
# M= 35106
# M= 0
# FLAG =  True
# 15.557306642240274
# 50
# M= 0
# FLAG =  True
# 15.650807600698982
# 51
# M= 70103
# M= 56
# M= 15
# M= 0
# FLAG =  True
# 15.321673813884729
# 52
# M= 0
# FLAG =  True
# 15.476832895713514
# 53
# M= 27336
# M= 3099
# M= 0
# FLAG =  True
# 15.415492548685531
# 54
# M= 55189
# M= 0
# FLAG =  True
# 15.379726744743657
# 55
# M= 10983
# M= 58413
# M= 5698
# M= 50879
# M= 0
# FLAG =  True
# 15.430455763421687
# 56
# M= 0
# FLAG =  True
# 15.512862850590503
# 57
# M= 71050
# M= 0
# FLAG =  True
# 15.373155064541933
# 58
# M= 47661
# M= 73763
# M= 0
# FLAG =  True
# 15.47308457411128
# 59
# M= 0
# FLAG =  True
# 15.378305210013
# 60
# M= 0
# FLAG =  True
# 15.548882156897282
# 61
# M= 0
# FLAG =  True
# 15.462801918539276
# 62
# M= 0
# FLAG =  True
# 15.360094602066999
# 63
# M= 54989
# M= 218
# M= 0
# FLAG =  True
# 15.454871315879068
# 64
# M= 0
# FLAG =  True
# 15.240106034139611
# 65
# M= 49823
# M= 0
# FLAG =  True
# 15.422967740742324
# 66
# M= 0
# FLAG =  True
# 15.365752866460484
# 67
# M= 23164
# M= 53716
# M= 0
# FLAG =  True
# 15.348976995657695
# 68
# M= 53476
# M= 0
# FLAG =  True
# 15.4536352683763
# 69
# M= 55635
# M= 6534
# M= 0
# FLAG =  True
# 15.418723926758858
# 70
# M= 46019
# M= 12364
# M= 0
# FLAG =  True
# 15.292151768183906
# 71
# M= 0
# FLAG =  True
# 15.273569689033053
# 72
# M= 0
# FLAG =  True
# 15.41940183373004
# 73
# M= 39555
# M= 7473
# M= 67402
# M= 0
# FLAG =  True
# 15.353255971135953
# 74
# M= 10512
# M= 0
# FLAG =  True
# 15.452870915288024
# 75
# M= 0
# FLAG =  True
# 15.513342353603106
# 76
# M= 2838
# M= 0
# FLAG =  True
# 15.501722173085735
# 77
# M= 0
# FLAG =  True
# 15.370460796200879
# 78
# M= 39270
# M= 15684
# M= 0
# FLAG =  True
# 15.399170778386745
# 79
# M= 0
# FLAG =  True
# 15.372956620941274
# 80
# M= 0
# FLAG =  True
# 15.400192468652884
# 81
# M= 73672
# M= 11054
# M= 41247
# M= 0
# FLAG =  True
# 15.522624595321265
# 82
# M= 0
# FLAG =  True
# 15.46143323209282
# 83
# M= 0
# FLAG =  True
# 15.728261630404313
# 84
# M= 70272
# M= 0
# FLAG =  True
# 15.761031526661295
# 85
# M= 36064
# M= 0
# FLAG =  True
# 15.52022054589919
# 86
# M= 68126
# M= 43384
# M= 0
# FLAG =  True
# 15.416858921133365
# 87
# M= 32029
# M= 0
# FLAG =  True
# 15.338612404167526
# 88
# M= 0
# FLAG =  True
# 15.482108622060148
# 89
# M= 0
# FLAG =  True
# 15.702457011929427
# 90
# M= 61257
# M= 0
# FLAG =  True
# 15.376132880406908
# 91
# M= 124485
# M= 0
# FLAG =  True
# 15.270387235796477
# 92
# M= 0
# FLAG =  True
# 15.52567207949085
# 93
# M= 40256
# M= 2625
# M= 3
# M= 83089
# M= 0
# FLAG =  True
# 15.556200962954541
# 94
# M= 54539
# M= 0
# FLAG =  True
# 15.478610774476596
# 95
# M= 0
# FLAG =  True
# 15.448257226760873
# 96
# M= 67331
# M= 10608
# M= 0
# FLAG =  True
# 15.30195857443397
# 97
# M= 47473
# M= 0
# FLAG =  True
# 15.368285068388154
# 98
# M= 70977
# M= 54996
# M= 0
# FLAG =  True
# 15.380100764495303
# 99
# M= 0
# FLAG =  True
# 15.519474519059782
# 100
# M= 0
# FLAG =  True
# 15.160203588172863
# 101
# M= 12197
# M= 0
# FLAG =  True
# 15.492370926223465
# 102
# M= 72608
# M= 0
# FLAG =  True
# 15.452183629700698
# 103
# M= 0
# FLAG =  True
# 15.404556872502626
# 104
# M= 58814
# M= 0
# FLAG =  True
# 15.599927446842567
# 105
# M= 771
# M= 0
# FLAG =  True
# 15.272022545086994
# 106
# M= 0
# FLAG =  True
# 15.332626246065443
# 107
# M= 9826
# M= 0
# FLAG =  True
# 15.504004891920971
# 108
# M= 55317
# M= 0
# FLAG =  True
# 15.363518763716145
# 109
# M= 63345
# M= 35291
# M= 0
# FLAG =  True
# 15.547967452417847
# 110
# M= 8279
# M= 21412
# M= 0
# FLAG =  True
# 15.481407570378748
# 111
# M= 1
# M= 68966
# M= 0
# FLAG =  True
# 15.337190442745612
# 112
# M= 10601
# M= 66362
# M= 1462
# M= 7288
# M= 40260
# FLAG =  False
# 1.5111906079668493
# 113
# M= 9583
# M= 64217
# M= 2427
# M= 11111
# M= 38635
# FLAG =  False
# 0.05551988288944052
# 114
# M= 9385
# M= 63882
# M= 2663
# M= 11556
# M= 38487
# FLAG =  False
# 0.013462738883887375
# 115
# M= 9340
# M= 63733
# M= 2728
# M= 11661
# M= 38511
# FLAG =  False
# 0.004840250537738923
# 116
# M= 9322
# M= 63625
# M= 2752
# M= 11716
# M= 38558
# FLAG =  False
# 0.0024186378230322114
# 117
# M= 9313
# M= 63547
# M= 2763
# M= 11740
# M= 38610
# FLAG =  False
# 0.001536572500616603
# 118
# M= 9311
# M= 63478
# M= 2767
# M= 11756
# M= 38661
# FLAG =  False
# 0.0011247068986993227
# 119
# M= 9310
# M= 63419
# M= 2768
# M= 11774
# M= 38702
# FLAG =  False
# 0.000781565337912332
# 120
# M= 9309
# M= 63360
# M= 2769
# M= 11797
# M= 38738
# FLAG =  False
# 0.000736257417021198
# 121
# M= 9310
# M= 63305
# M= 2769
# M= 11817
# M= 38772
# FLAG =  False
# 0.0006650644066893365
# 122
# M= 9311
# M= 63263
# M= 2769
# M= 11824
# M= 38806
# FLAG =  False
# 0.0005830782573468536
# 123
# M= 9311
# M= 63219
# M= 2769
# M= 11837
# M= 38837
# FLAG =  False
# 0.0005464224186596558
# 124
# M= 9311
# M= 63178
# M= 2769
# M= 11862
# M= 38853
# FLAG =  False
# 0.0003949965979737291
# 125
# M= 9311
# M= 63149
# M= 2769
# M= 11872
# M= 38872
# FLAG =  False
# 0.00034654756290105227
# 126
# M= 9311
# M= 63112
# M= 2769
# M= 11898
# M= 38883
# FLAG =  False
# 0.00032491709417980304
# 127
# M= 9311
# M= 63091
# M= 2769
# M= 11910
# M= 38892
# FLAG =  False
# 0.00020834758103852518
# 128
# M= 9311
# M= 63068
# M= 2769
# M= 11923
# M= 38902
# FLAG =  False
# 0.0002291571487888636
# 129
# M= 9311
# M= 63049
# M= 2769
# M= 11935
# M= 38909
# FLAG =  False
# 0.00017798612540474257
# 130
# M= 9311
# M= 63029
# M= 2769
# M= 11950
# M= 38914
# FLAG =  False
# 0.0001662866141913599
# 131
# M= 9311
# M= 63015
# M= 2769
# M= 11959
# M= 38919
# FLAG =  False
# 0.00012945896040930693
# 132
# M= 9311
# M= 63002
# M= 2769
# M= 11968
# M= 38923
# FLAG =  False
# 0.00011446290736408944
# 133
# M= 9311
# M= 62995
# M= 2769
# M= 11973
# M= 38925
# FLAG =  False
# 6.024318405765273e-05
# 134
# M= 9311
# M= 62990
# M= 2769
# M= 11975
# M= 38928
# FLAG =  False
# 5.683734534238591e-05
# 135
# M= 9311
# M= 62985
# M= 2769
# M= 11978
# M= 38930
# FLAG =  False
# 4.803024071850428e-05
# 136
# M= 9311
# M= 62983
# M= 2769
# M= 11979
# M= 38931
# FLAG =  False
# 2.0968289288091925e-05
# 137
# M= 9311
# M= 62981
# M= 2769
# M= 11980
# M= 38932
# FLAG =  False
# 2.0965560029377175e-05
# 138
# M= 9311
# M= 62980
# M= 2769
# M= 11980
# M= 38933
# FLAG =  False
# 1.4879823507108628e-05
# 139
# M= 9311
# M= 62980
# M= 2769
# M= 11980
# M= 38933
# FLAG =  False
# 0.0
# 140

# %%
# for i in range(k):
#     distances[:,i] = np.linalg.norm(X - centers_new[i], axis=1)
    
# clusters = np.argmin(distances, axis = 1)

# %%
clusters

# centers_new
# Out:
# array([1, 4, 4, ..., 3, 4, 1])

# %%
cont = contingency_matrix(clusters,Y)
print(cont)
# Out:
# [[   81  6885    49  2296     0]
#  [55860  2093   672  4325    30]
#  [   49     0     0  2720     0]
#  [ 7644  3169   264   882    21]
#  [ 3709 33780    10  1433     1]]

# %%
ans = 0
for i in cont:
    ans = ans + max(i)
purity = ans/len(df)
print(purity)
# Out:
# 0.8485072198010685
